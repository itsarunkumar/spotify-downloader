# %%
import requests
from bs4 import BeautifulSoup

headers = {
    "User-Agent": "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:91.0) Gecko/20100101 Firefox/91.0"
}

# url = "https://www.chosic.com/free-music/all/"
# soup = BeautifulSoup(requests.get(url).content, "html.parser")

# for u in soup.select("[data-url]"):
#     u = u["data-url"]
#     print("Downloading {}".format(u))
#     with open(u.split("/")[-1], "wb") as f_out:
#         f_out.write(requests.get(u, headers=headers).content)

# %%
url = "https://masstamilan.dev/music/harris-jayaraj?sort=latest"
content = requests.get(url).content
content = BeautifulSoup(content, "html.parser")
content
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <title>Harris Jayaraj Hits - Movies of Harris Jayaraj | Masstamilan.dev</title>
# <meta content="Harris Jayaraj songs download masstamilan, Harris Jayaraj hits masstamilan,Download Harris Jayaraj movie songs Tamil in zip/rar format at Masstamilan.dev" name="description"/>
# <meta content="harris jayaraj hits, harris jayaraj tamil mp3, harris jayaraj tamil movie songs download, harris jayaraj free mp3, harris jayaraj songs zip, harris jayaraj songs rar, harris jayaraj high quality songs" name="keywords"/>
# <meta content="Masstamilan.dev" property="og:site_name"/>
# <meta content="Harris Jayaraj Hits - Movies of Harris Jayaraj" property="og:title"/>
# <meta content="Harris Jayaraj songs download masstamilan, Harris Jayaraj hits masstamilan,Download Harris Jayaraj movie songs Tamil in zip/rar format at Masstamilan.dev" property="og:description"/>
# <meta content="https://masstamilan.dev/music/Harris Jayaraj" property="og:url"/>
# ...

# %%
content = content.select('.botlist')
content
# Out:
# [<div class="botlist">
#  <div class="a-i">
#  <a href="/12b-songs" rel="bookmark" title="12B Songs Download">
#  <div>
#  <div class="ava">
#  <picture>
#  <source srcset="/i/wp/12b.webp" type="image/webp"/>
#  <source srcset="/i/img/12b.jpg" type="image/jpeg"/>
#  <img alt="12B movie poster" loading="lazy" src="/i/img/12b.jpg" title="12B Movie Poster"/>
#  </picture>
#  </div>
#  <div class="info">
#  <h2>12B</h2>
#  <p class="description">
#  <b>Starring:</b> Shaam, Simran, Jyotika<br/>
#  <b>Music:</b> Harris Jayaraj<br/>
#  <b>Director:</b> Jeeva, K. Bhagyaraja (screenplay)
#  </p>
#  </div>
#  </div>
#  </a>
#  </div>
#  <div class="a-i">
#  <a href="/7-aum-arivu-songs" rel="bookmark" title="7 Aum Arivu(7aam Arivu) Songs Download">
#  <div>
#  <div class="ava">
#  <picture>
#  <source srcset="/i/wp/7-aum-arivu-7aam-arivu-2010.webp" type="image/webp"/>
#  <source srcset="/i/img/7-aum-arivu-7aam-arivu-2010.jpg" type="image/jpeg"/>
# ...

# %%
for i in content:
    print(i.select('a')[0]['href'])

single = content[0].select('a')[0]['href']
single
# Out:
# /12b-songs
# '/12b-songs'

# %%
single_movie = requests.get(url+single)
single_movie = BeautifulSoup(single_movie.content, "html.parser")
single_movie
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <title>Harris Jayaraj Hits - Movies of Harris Jayaraj | Masstamilan.dev</title>
# <meta content="Harris Jayaraj songs download masstamilan, Harris Jayaraj hits masstamilan,Download Harris Jayaraj movie songs Tamil in zip/rar format at Masstamilan.dev" name="description"/>
# <meta content="harris jayaraj hits, harris jayaraj tamil mp3, harris jayaraj tamil movie songs download, harris jayaraj free mp3, harris jayaraj songs zip, harris jayaraj songs rar, harris jayaraj high quality songs" name="keywords"/>
# <meta content="Masstamilan.dev" property="og:site_name"/>
# <meta content="Harris Jayaraj Hits - Movies of Harris Jayaraj" property="og:title"/>
# <meta content="Harris Jayaraj songs download masstamilan, Harris Jayaraj hits masstamilan,Download Harris Jayaraj movie songs Tamil in zip/rar format at Masstamilan.dev" property="og:description"/>
# <meta content="https://masstamilan.dev/music/Harris Jayaraj" property="og:url"/>
# ...

# %%
single_movie = single_movie.find_all('a')
single_movie
# Out:
# [<a class="logo mt-dev logo1" href="/" title="MassTamilan">MassTamilan</a>,
#  <a class="menu-icon" href="#" style="display:none">
#  <svg viewbox="0 0 18 15">
#  <path d="M18,1.484c0,0.82-0.665,1.484-1.484,1.484H1.484C0.665,2.969,0,2.304,0,1.484l0,0C0,0.665,0.665,0,1.484,0 h15.031C17.335,0,18,0.665,18,1.484L18,1.484z"></path>
#  <path d="M18,7.516C18,8.335,17.335,9,16.516,9H1.484C0.665,9,0,8.335,0,7.516l0,0c0-0.82,0.665-1.484,1.484-1.484 h15.031C17.335,6.031,18,6.696,18,7.516L18,7.516z"></path>
#  <path d="M18,13.516C18,14.335,17.335,15,16.516,15H1.484C0.665,15,0,14.335,0,13.516l0,0 c0-0.82,0.665-1.484,1.484-1.484h15.031C17.335,12.031,18,12.696,18,13.516L18,13.516z"></path>
#  </svg>
#  </a>,
#  <a class="page-link anim slink" href="/search" rel="bookmark" style="display:none">Search</a>,
#  <a class="page-link anim" href="/latest-updates" rel="bookmark">Latest Updates</a>,
#  <a class="page-link anim" href="/movie-index" rel="bookmark">Movie Index</a>,
# ...
